# %% [markdown]
# # Machine Translator

# %% [markdown]
# For this project, we will be building a translation tool using Keras models with seq2seq neural networks! This model will be a character-level translation.

# %%
## To allow for GPU computation
import os
os.add_dll_directory("C:/Program Files/NVIDIA GPU Computing Toolkit/CUDA/v11.7/bin")

## Library Imports
import numpy as np
import tensorflow as tf
from tensorflow import keras
import re
from keras.layers import Input, LSTM, Dense
from keras.models import Model, load_model

# %%
## Model Hyperparameters
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.

# %%
## Import training translations
data_path = "fra.txt"

# Define lines as a list of each line
with open(data_path, 'r', encoding='utf-8') as f:
  lines = f.read().split('\n')

# %%
## Data Preprocessing
# Building empty lists to hold sentences
input_docs = []
target_docs = []
# Building empty vocabulary sets
input_tokens = set()
target_tokens = set()

for line in lines[:min(num_samples, len(lines)-1)]:
    input_doc, target_doc = line.split('\t')[:2]
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_doc = "\t" + target_doc + "\n"
    input_docs.append(input_doc)
    target_docs.append(target_doc)

    # Now we split up each sentence into words
    # and add each unique word to our vocabulary set
    for token in input_doc:
        if token not in input_tokens:
            input_tokens.add(token)
    
    for token in target_doc:
        if token not in target_tokens:
            target_tokens.add(token)

input_tokens = sorted(list(input_tokens))
target_tokens = sorted(list(target_tokens))
num_encoder_tokens = len(input_tokens)
num_decoder_tokens = len(target_tokens)
max_encoder_seq_length = max([len(txt) for txt in input_docs])
max_decoder_seq_length = max([len(txt) for txt in target_docs])

print("Number of samples:", len(input_docs))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)

# For one-hot encoding, create a token to index dictionary
# Tokens are really just characters
input_features_dict = dict(
    [(token, i) for i, token in enumerate(input_tokens)])
target_features_dict = dict(
    [(token, i) for i, token in enumerate(target_tokens)])

# Encoder and Decoder accepts vectors as input, let's vectorize. 
# These matrices will hold the one-hot encodings for every character of every word of every sentence
encoder_input_data = np.zeros(
    (len(input_docs), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_docs), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_docs), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

# Populate the above matrices
for line, (input_doc, target_doc) in enumerate(zip(input_docs, target_docs)):

    for timestep, token in enumerate(input_doc):
        encoder_input_data[line, timestep, input_features_dict[token]] = 1.0
    encoder_input_data[line, timestep + 1 :, input_features_dict[" "]] = 1.0

    for timestep, token in enumerate(target_doc):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        # Technique of 'teacher forcing'
        decoder_input_data[line, timestep, target_features_dict[token]] = 1.0
        if timestep > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[line, timestep - 1, target_features_dict[token]] = 1.0
    decoder_input_data[line, timestep + 1 :, target_features_dict[" "]] = 1.0
    decoder_target_data[line, timestep:, target_features_dict[" "]] = 1.0
# Out:
# Number of samples: 10000
# Number of unique input tokens: 71
# Number of unique output tokens: 93
# Max sequence length for inputs: 15
# Max sequence length for outputs: 59

# %%
## Building the Model
# Define an input sequence and process it 
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder_lstm = LSTM(latent_dim, return_state=True)
encoder_outputs, state_hidden, state_cell = encoder_lstm(encoder_inputs)

# Discard 'encoder_outputs' and keep only the states
encoder_states = [state_hidden, state_cell]

# Set up the decoder using 'encoder_states' as initial state
decoder_inputs = Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will be trained, this sets up the model parameters
training_model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
## Training the Model
training_model.compile(
    optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy']
)

training_model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
)

training_model.save('training_model.h5')
# Out:
# Epoch 1/100
# 125/125 [==============================] - 4s 15ms/step - loss: 1.1498 - accuracy: 0.7357 - val_loss: 1.0582 - val_accuracy: 0.7113
# Epoch 2/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.8329 - accuracy: 0.7771 - val_loss: 0.8364 - val_accuracy: 0.7700
# Epoch 3/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.6639 - accuracy: 0.8148 - val_loss: 0.6965 - val_accuracy: 0.8008
# Epoch 4/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.5725 - accuracy: 0.8342 - val_loss: 0.6285 - val_accuracy: 0.8192
# Epoch 5/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.5226 - accuracy: 0.8471 - val_loss: 0.5839 - val_accuracy: 0.8315
# Epoch 6/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.4874 - accuracy: 0.8570 - val_loss: 0.5541 - val_accuracy: 0.8395
# Epoch 7/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.4607 - accuracy: 0.8639 - val_loss: 0.5373 - val_accuracy: 0.8424
# Epoch 8/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4374 - accuracy: 0.8701 - val_loss: 0.5147 - val_accuracy: 0.8493
# Epoch 9/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4173 - accuracy: 0.8757 - val_loss: 0.5076 - val_accuracy: 0.8500
# Epoch 10/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3992 - accuracy: 0.8802 - val_loss: 0.4892 - val_accuracy: 0.8564
# Epoch 11/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3828 - accuracy: 0.8849 - val_loss: 0.4816 - val_accuracy: 0.8580
# Epoch 12/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3680 - accuracy: 0.8892 - val_loss: 0.4710 - val_accuracy: 0.8611
# Epoch 13/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3535 - accuracy: 0.8935 - val_loss: 0.4662 - val_accuracy: 0.8635
# Epoch 14/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3400 - accuracy: 0.8977 - val_loss: 0.4570 - val_accuracy: 0.8661
# Epoch 15/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3276 - accuracy: 0.9012 - val_loss: 0.4552 - val_accuracy: 0.8673
# Epoch 16/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3158 - accuracy: 0.9050 - val_loss: 0.4469 - val_accuracy: 0.8701
# Epoch 17/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3044 - accuracy: 0.9082 - val_loss: 0.4480 - val_accuracy: 0.8710
# Epoch 18/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2938 - accuracy: 0.9112 - val_loss: 0.4455 - val_accuracy: 0.8721
# Epoch 19/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2833 - accuracy: 0.9144 - val_loss: 0.4436 - val_accuracy: 0.8733
# Epoch 20/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2734 - accuracy: 0.9178 - val_loss: 0.4390 - val_accuracy: 0.8743
# Epoch 21/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2642 - accuracy: 0.9202 - val_loss: 0.4451 - val_accuracy: 0.8732
# Epoch 22/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2553 - accuracy: 0.9228 - val_loss: 0.4453 - val_accuracy: 0.8741
# Epoch 23/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2467 - accuracy: 0.9252 - val_loss: 0.4417 - val_accuracy: 0.8758
# Epoch 24/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2386 - accuracy: 0.9275 - val_loss: 0.4466 - val_accuracy: 0.8746
# Epoch 25/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2309 - accuracy: 0.9300 - val_loss: 0.4486 - val_accuracy: 0.8754
# Epoch 26/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2230 - accuracy: 0.9323 - val_loss: 0.4527 - val_accuracy: 0.8749
# Epoch 27/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2160 - accuracy: 0.9344 - val_loss: 0.4549 - val_accuracy: 0.8757
# Epoch 28/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2089 - accuracy: 0.9364 - val_loss: 0.4552 - val_accuracy: 0.8765
# Epoch 29/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2025 - accuracy: 0.9385 - val_loss: 0.4561 - val_accuracy: 0.8761
# Epoch 30/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1960 - accuracy: 0.9402 - val_loss: 0.4645 - val_accuracy: 0.8747
# Epoch 31/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1898 - accuracy: 0.9423 - val_loss: 0.4707 - val_accuracy: 0.8753
# Epoch 32/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1841 - accuracy: 0.9439 - val_loss: 0.4694 - val_accuracy: 0.8753
# Epoch 33/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1785 - accuracy: 0.9457 - val_loss: 0.4735 - val_accuracy: 0.8762
# Epoch 34/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1732 - accuracy: 0.9472 - val_loss: 0.4786 - val_accuracy: 0.8763
# Epoch 35/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1678 - accuracy: 0.9489 - val_loss: 0.4851 - val_accuracy: 0.8762
# Epoch 36/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1629 - accuracy: 0.9503 - val_loss: 0.4900 - val_accuracy: 0.8747
# Epoch 37/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1580 - accuracy: 0.9516 - val_loss: 0.4924 - val_accuracy: 0.8745
# Epoch 38/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1537 - accuracy: 0.9530 - val_loss: 0.4929 - val_accuracy: 0.8769
# Epoch 39/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1490 - accuracy: 0.9543 - val_loss: 0.5025 - val_accuracy: 0.8762
# Epoch 40/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1449 - accuracy: 0.9554 - val_loss: 0.5069 - val_accuracy: 0.8762
# Epoch 41/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1412 - accuracy: 0.9567 - val_loss: 0.5088 - val_accuracy: 0.8763
# Epoch 42/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1370 - accuracy: 0.9578 - val_loss: 0.5160 - val_accuracy: 0.8751
# Epoch 43/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1333 - accuracy: 0.9590 - val_loss: 0.5193 - val_accuracy: 0.8753
# Epoch 44/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1298 - accuracy: 0.9600 - val_loss: 0.5272 - val_accuracy: 0.8749
# Epoch 45/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1262 - accuracy: 0.9611 - val_loss: 0.5258 - val_accuracy: 0.8763
# Epoch 46/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1229 - accuracy: 0.9623 - val_loss: 0.5371 - val_accuracy: 0.8748
# Epoch 47/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1199 - accuracy: 0.9628 - val_loss: 0.5435 - val_accuracy: 0.8749
# Epoch 48/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1165 - accuracy: 0.9639 - val_loss: 0.5474 - val_accuracy: 0.8729
# Epoch 49/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1139 - accuracy: 0.9647 - val_loss: 0.5534 - val_accuracy: 0.8746
# Epoch 50/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1108 - accuracy: 0.9655 - val_loss: 0.5568 - val_accuracy: 0.8744
# Epoch 51/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1081 - accuracy: 0.9662 - val_loss: 0.5600 - val_accuracy: 0.8747
# Epoch 52/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1056 - accuracy: 0.9670 - val_loss: 0.5687 - val_accuracy: 0.8740
# Epoch 53/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1033 - accuracy: 0.9674 - val_loss: 0.5719 - val_accuracy: 0.8745
# Epoch 54/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1004 - accuracy: 0.9684 - val_loss: 0.5817 - val_accuracy: 0.8732
# Epoch 55/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0980 - accuracy: 0.9694 - val_loss: 0.5827 - val_accuracy: 0.8741
# Epoch 56/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0961 - accuracy: 0.9696 - val_loss: 0.5876 - val_accuracy: 0.8745
# Epoch 57/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0941 - accuracy: 0.9703 - val_loss: 0.5996 - val_accuracy: 0.8728
# Epoch 58/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0917 - accuracy: 0.9710 - val_loss: 0.5930 - val_accuracy: 0.8744
# Epoch 59/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0897 - accuracy: 0.9714 - val_loss: 0.6072 - val_accuracy: 0.8724
# Epoch 60/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0876 - accuracy: 0.9720 - val_loss: 0.6097 - val_accuracy: 0.8729
# Epoch 61/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0858 - accuracy: 0.9726 - val_loss: 0.6148 - val_accuracy: 0.8733
# Epoch 62/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0838 - accuracy: 0.9732 - val_loss: 0.6124 - val_accuracy: 0.8732
# Epoch 63/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0819 - accuracy: 0.9736 - val_loss: 0.6260 - val_accuracy: 0.8740
# Epoch 64/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0805 - accuracy: 0.9739 - val_loss: 0.6272 - val_accuracy: 0.8731
# Epoch 65/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0788 - accuracy: 0.9746 - val_loss: 0.6370 - val_accuracy: 0.8722
# Epoch 66/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0772 - accuracy: 0.9749 - val_loss: 0.6396 - val_accuracy: 0.8711
# Epoch 67/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0756 - accuracy: 0.9756 - val_loss: 0.6446 - val_accuracy: 0.8725
# Epoch 68/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0742 - accuracy: 0.9759 - val_loss: 0.6413 - val_accuracy: 0.8726
# Epoch 69/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0727 - accuracy: 0.9766 - val_loss: 0.6502 - val_accuracy: 0.8718
# Epoch 70/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0713 - accuracy: 0.9766 - val_loss: 0.6550 - val_accuracy: 0.8725
# Epoch 71/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0697 - accuracy: 0.9770 - val_loss: 0.6653 - val_accuracy: 0.8703
# Epoch 72/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0686 - accuracy: 0.9775 - val_loss: 0.6636 - val_accuracy: 0.8712
# Epoch 73/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0672 - accuracy: 0.9776 - val_loss: 0.6635 - val_accuracy: 0.8718
# Epoch 74/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0660 - accuracy: 0.9783 - val_loss: 0.6676 - val_accuracy: 0.8716
# Epoch 75/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0650 - accuracy: 0.9786 - val_loss: 0.6790 - val_accuracy: 0.8713
# Epoch 76/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0637 - accuracy: 0.9789 - val_loss: 0.6801 - val_accuracy: 0.8714
# Epoch 77/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0624 - accuracy: 0.9791 - val_loss: 0.6837 - val_accuracy: 0.8720
# Epoch 78/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0615 - accuracy: 0.9795 - val_loss: 0.6866 - val_accuracy: 0.8709
# Epoch 79/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0605 - accuracy: 0.9798 - val_loss: 0.6848 - val_accuracy: 0.8726
# Epoch 80/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0594 - accuracy: 0.9802 - val_loss: 0.6865 - val_accuracy: 0.8719
# Epoch 81/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0585 - accuracy: 0.9802 - val_loss: 0.6991 - val_accuracy: 0.8711
# Epoch 82/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0574 - accuracy: 0.9806 - val_loss: 0.6951 - val_accuracy: 0.8716
# Epoch 83/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0565 - accuracy: 0.9808 - val_loss: 0.7112 - val_accuracy: 0.8714
# Epoch 84/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0555 - accuracy: 0.9810 - val_loss: 0.7137 - val_accuracy: 0.8707
# Epoch 85/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0549 - accuracy: 0.9812 - val_loss: 0.7118 - val_accuracy: 0.8713
# Epoch 86/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0542 - accuracy: 0.9815 - val_loss: 0.7227 - val_accuracy: 0.8700
# Epoch 87/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0532 - accuracy: 0.9818 - val_loss: 0.7194 - val_accuracy: 0.8717
# Epoch 88/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0525 - accuracy: 0.9820 - val_loss: 0.7290 - val_accuracy: 0.8696
# Epoch 89/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0516 - accuracy: 0.9821 - val_loss: 0.7281 - val_accuracy: 0.8714
# Epoch 90/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0509 - accuracy: 0.9824 - val_loss: 0.7336 - val_accuracy: 0.8705
# Epoch 91/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0506 - accuracy: 0.9824 - val_loss: 0.7339 - val_accuracy: 0.8713
# Epoch 92/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0496 - accuracy: 0.9827 - val_loss: 0.7372 - val_accuracy: 0.8700
# Epoch 93/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0489 - accuracy: 0.9827 - val_loss: 0.7409 - val_accuracy: 0.8708
# Epoch 94/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0485 - accuracy: 0.9831 - val_loss: 0.7471 - val_accuracy: 0.8694
# Epoch 95/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0478 - accuracy: 0.9831 - val_loss: 0.7490 - val_accuracy: 0.8707
# Epoch 96/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0470 - accuracy: 0.9834 - val_loss: 0.7560 - val_accuracy: 0.8700
# Epoch 97/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0466 - accuracy: 0.9835 - val_loss: 0.7526 - val_accuracy: 0.8701
# Epoch 98/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0460 - accuracy: 0.9836 - val_loss: 0.7630 - val_accuracy: 0.8687
# Epoch 99/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0456 - accuracy: 0.9839 - val_loss: 0.7570 - val_accuracy: 0.8706
# Epoch 100/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0451 - accuracy: 0.9839 - val_loss: 0.7642 - val_accuracy: 0.8699

# %%
## Setup for Testing
# Define sampling models
# Restore the model and construct the encoder and decoder.
# Note: the model we used for training our network only works when we already know the target sequence. 
# This time, we have no idea what the Spanish should be for the English we pass in! 
# So we need a model that will decode step-by-step instead of using teacher forcing.
training_model = load_model('training_model.h5')

encoder_inputs = training_model.input[0] 
encoder_outputs, state_h_enc, state_c_enc = training_model.layers[2].output
encoder_states = [state_h_enc, state_c_enc]
encoder_model = Model(encoder_inputs, encoder_states)

decoder_inputs = training_model.input[1]
decoder_state_input_hidden = Input(shape=(latent_dim,))
decoder_state_input_cell = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_hidden, decoder_state_input_cell]

decoder_lstm = training_model.layers[3]
decoder_outputs, state_hidden, state_cell = decoder_lstm(decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_hidden, state_cell]

decoder_dense = training_model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states)

# Create a index to token dictionary 
reverse_input_features_dict = dict(
    (i, token) for token, i in input_features_dict.items())
reverse_target_features_dict = dict(
    (i, token) for token, i in target_features_dict.items())

def decode_sequence(test_input):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(test_input)

    # Generate empty target sequence of length 1. 
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first token of target sequence with the start token.capitalize
    target_seq[0, 0, target_features_dict['\t']] = 1.0

    # Sampling loop for a batch of sequences 
    stop_condition = False
    decoded_sentence = ''

    while not stop_condition:
        # Run the decoder model to get possible output tokens (with probabilities) & states
        output_tokens, hidden_state, cell_state = decoder_model.predict(
            [target_seq] + states_value)

        # Choose token with highest probability
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_features_dict[sampled_token_index]
        decoded_sentence += sampled_token

        # Exit condition: either hit max length or find stop token
        if (sampled_token == '\n' or len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True
        
        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [hidden_state, cell_state]
    return decoded_sentence

# %%
## Testing
for seq_index in range(20):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    seq_index += 100
    test_input = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(test_input)
    print('-')
    print('Input sentence:', input_docs[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: Hop in.
# Decoded sentence: Montez.
#
# -
# Input sentence: Hug me.
# Decoded sentence: Serrez-moi dans vos bras !
#
# -
# Input sentence: Hug me.
# Decoded sentence: Serrez-moi dans vos bras !
#
# -
# Input sentence: I fell.
# Decoded sentence: Je suis tombée.
#
# -
# Input sentence: I fell.
# Decoded sentence: Je suis tombée.
#
# -
# Input sentence: I fled.
# Decoded sentence: J'ai fui.
#
# -
# Input sentence: I knit.
# Decoded sentence: Je tricote.
#
# -
# Input sentence: I know.
# Decoded sentence: Je sais.
#
# -
# Input sentence: I left.
# Decoded sentence: Je suis partie.
#
# -
# Input sentence: I left.
# Decoded sentence: Je suis partie.
#
# -
# Input sentence: I lied.
# Decoded sentence: J'ai menti.
#
# -
# Input sentence: I lost.
# Decoded sentence: J'ai perdu.
#
# -
# Input sentence: I paid.
# Decoded sentence: Je payai.
#
# -
# Input sentence: I paid.
# Decoded sentence: Je payai.
#
# -
# Input sentence: I paid.
# Decoded sentence: Je payai.
#
# -
# Input sentence: I quit.
# Decoded sentence: J'arrête.
#
# -
# Input sentence: I quit.
# Decoded sentence: J'arrête.
#
# -
# Input sentence: I'm 19.
# Decoded sentence: J'ai 19 ans.
#
# -
# Input sentence: I'm OK.
# Decoded sentence: Je vais bien.
#
# -
# Input sentence: I'm OK.
# Decoded sentence: Je vais bien.

# %% [markdown]
# The current model works quite well for English-French. However, it performs poorly with a English-Spanish translation. Next steps are to employ Word2Vec in place of one-hot encodings to allow for context to be tracked and allow for faster computation.
